# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
Raw_DIR= r'C:\Users\Varun Bharadwaj\Desktop\New folder\mrlEyes_2018_01'
for dirpath, dirname, filenames in os.walk(Raw_DIR):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4]=='0':
            shutil.copy(src=dirpath+'/'+i, dst= r'C:\Users\Varun Bharadwaj\Desktop\New folder\Prepared_data\Close_eyes')
            
        elif i.split('_')[4]=='1':
            shutil.copy(src=dirpath+'/'+i, dst= r'C:\Users\Varun Bharadwaj\Desktop\New folder\Prepared_data\Open_eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [02:43<00:00, 62.75it/s]
